# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
data = pd.read_csv('Life_Expectancy Data.csv')

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu', ax = ax)

# %%
data.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
data['Status'] = data.Status.map({'Developing':0, 'Developed':1})

# %%
data.head()
# Out:
#        Country  Year  Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015       0              65.0            263.0
# 1  Afghanistan  2014       0              59.9            271.0
# 2  Afghanistan  2013       0              59.9            268.0
# 3  Afghanistan  2012       0              59.5            272.0
# 4  Afghanistan  2011       0              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   19.1                  83    6.0               8.16         65.0
# ...

# %%
data.drop('Year', inplace=True, axis=1)

# %%
data.head()
# Out:
#        Country  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan       0              65.0            263.0             62
# 1  Afghanistan       0              59.9            271.0             64
# 2  Afghanistan       0              59.9            268.0             66
# 3  Afghanistan       0              59.5            272.0             69
# 4  Afghanistan       0              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# 0     0.01               71.279624         65.0      1154   19.1
# 1     0.01               73.523582         62.0       492   18.6
# 2     0.01               73.219243         64.0       430   18.1
# 3     0.01               78.184215         67.0      2787   17.6
# 4     0.01                7.097109         68.0      3013   17.2
#
#    under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
data.drop('Country', inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['Status', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.head()
# Out:
#    Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0       0              65.0            263.0             62     0.01
# 1       0              59.9            271.0             64     0.01
# 2       0              59.9            268.0             66     0.01
# 3       0              59.5            272.0             69     0.01
# 4       0              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.drop('under-five deaths ', axis=1, inplace=True)

# %%
data.drop(['Measles ', 'infant deaths'], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
#  BMI                                34
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.shape
# Out:
# (2938, 17)

# %%
#new = pd.concat([y,x], axis=1)
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu', ax = ax)

# %%
data.drop(['Hepatitis B', 'Total expenditure'], axis = 1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# percentage expenditure               0
#  BMI                                34
# Polio                               19
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.shape
# Out:
# (2938, 15)

# %%
data.describe()
# Out:
#             Status  Life expectancy   Adult Mortality      Alcohol  \
# count  2938.000000       2928.000000      2928.000000  2744.000000
# mean      0.174268         69.224932       164.796448     4.602861
# std       0.379405          9.523867       124.292079     4.052413
# min       0.000000         36.300000         1.000000     0.010000
# 25%       0.000000         63.100000        74.000000     0.877500
# 50%       0.000000         72.100000       144.000000     3.755000
# 75%       0.000000         75.700000       228.000000     7.702500
# max       1.000000         89.000000       723.000000    17.870000
#
#        percentage expenditure         BMI         Polio  Diphtheria   \
# count             2938.000000  2904.000000  2919.000000  2919.000000
# mean               738.251295    38.321247    82.550188    82.324084
# std               1987.914858    20.044034    23.428046    23.716912
# min                  0.000000     1.000000     3.000000     2.000000
# ...

# %%
data[data['GDP'].isnull()].Status.describe()
# Out:
# count    448.000000
# mean       0.142857
# std        0.350318
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: Status, dtype: float64

# %%
data.drop(['GDP'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    Status  Life expectancy   Adult Mortality  Alcohol  percentage expenditure  \
# 0       0              65.0            263.0     0.01               71.279624
# 1       0              59.9            271.0     0.01               73.523582
# 2       0              59.9            268.0     0.01               73.219243
# 3       0              59.5            272.0     0.01               78.184215
# 4       0              59.2            275.0     0.01                7.097109
#
#     BMI   Polio  Diphtheria    HIV/AIDS  Population   thinness  1-19 years  \
# 0   19.1    6.0         65.0        0.1  33736494.0                   17.2
# 1   18.6   58.0         62.0        0.1    327582.0                   17.5
# 2   18.1   62.0         64.0        0.1  31731688.0                   17.7
# 3   17.6   67.0         67.0        0.1   3696958.0                   17.9
# 4   17.2   68.0         68.0        0.1   2978599.0                   18.2
#
# ...

# %%
#new = pd.concat([y,x], axis=1)
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu', ax = ax)

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# percentage expenditure               0
#  BMI                                34
# Polio                               19
# Diphtheria                          19
#  HIV/AIDS                            0
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
print(data.columns)
data.describe()
# Out:
# Index(['Status', 'Life expectancy ', 'Adult Mortality', 'Alcohol',
#        'percentage expenditure', ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS',
#        'Population', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
#             Status  Life expectancy   Adult Mortality      Alcohol  \
# count  2938.000000       2928.000000      2928.000000  2744.000000
# mean      0.174268         69.224932       164.796448     4.602861
# std       0.379405          9.523867       124.292079     4.052413
# min       0.000000         36.300000         1.000000     0.010000
# 25%       0.000000         63.100000        74.000000     0.877500
# 50%       0.000000         72.100000       144.000000     3.755000
# 75%       0.000000         75.700000       228.000000     7.702500
# max       1.000000         89.000000       723.000000    17.870000
#
# ...

# %%
print(data['Alcohol'].mean())
print(data['Alcohol'].median())
# Out:
# 4.6028607871720375
# 3.755

# %%
data['Alcohol']=data['Alcohol'].fillna(3.75)

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                              0
# percentage expenditure               0
#  BMI                                34
# Polio                               19
# Diphtheria                          19
#  HIV/AIDS                            0
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.shape
# Out:
# (2938, 14)

# %%
data.drop('Population', axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                              0
# percentage expenditure               0
#  BMI                                34
# Polio                               19
# Diphtheria                          19
#  HIV/AIDS                            0
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.shape
# Out:
# (2938, 13)

# %%
data['Income composition of resources'].fillna(0.677, inplace=True)

# %%
data['Schooling'].fillna(12.30,inplace=True)

# %%
data.isnull().sum()
# Out:
# Status                              0
# Life expectancy                    10
# Adult Mortality                    10
# Alcohol                             0
# percentage expenditure              0
#  BMI                               34
# Polio                              19
# Diphtheria                         19
#  HIV/AIDS                           0
#  thinness  1-19 years              34
#  thinness 5-9 years                34
# Income composition of resources     0
# Schooling                           0
# dtype: int64

# %%
print(data.shape)
data.dropna(inplace=True)
print(data.shape)
# Out:
# (2938, 13)
# (2888, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(['Life expectancy '], axis = 1)

# %%
y = data['Life expectancy ']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression() 
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.804379618552483

# %%
linear_model.score(x_test, y_test)
# Out:
# 0.804379618552483

# %%
linear_model.intercept_
# Out:
# 52.06499202082557

# %%
print(linear_model.coef_)
# Out:
# [ 1.62798435e+00 -1.79515536e-02  1.68536862e-02  2.40381289e-04
#   4.19729230e-02  3.25342614e-02  4.00289726e-02 -4.87373147e-01
#  -9.14336471e-02 -3.23316568e-02  8.42400039e+00  6.70960350e-01]

# %% [markdown]
# ## Select K Best

# %%
from sklearn.feature_selection import f_regression, SelectKBest

# %%
k_best = SelectKBest(f_regression, k=7)
k_best.fit(x,y)
# Out:
# SelectKBest(k=7, score_func=<function f_regression at 0x7fca7f91b440>)

# %%
k_best.get_params()
# Out:
# {'k': 7,
#  'score_func': <function sklearn.feature_selection._univariate_selection.f_regression(X, y, center=True)>}

# %%
x.columns[k_best.get_support(indices=True)]
# Out:
# Index(['Status', 'Adult Mortality', ' BMI ', 'Diphtheria ', ' HIV/AIDS',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu', ax = ax)

# %%
indices = k_best.get_support(indices=True)
print(indices)
# Out:
# [ 0  1  4  6  7 10 11]

# %%
x.columns[indices]
# Out:
# Index(['Status', 'Adult Mortality', ' BMI ', 'Diphtheria ', ' HIV/AIDS',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
x.iloc[:,indices]
# Out:
#       Status  Adult Mortality   BMI   Diphtheria    HIV/AIDS  \
# 0          0            263.0   19.1         65.0        0.1
# 1          0            271.0   18.6         62.0        0.1
# 2          0            268.0   18.1         64.0        0.1
# 3          0            272.0   17.6         67.0        0.1
# 4          0            275.0   17.2         68.0        0.1
# ...      ...              ...    ...          ...        ...
# 2933       0            723.0   27.1         65.0       33.6
# 2934       0            715.0   26.7         68.0       36.7
# 2935       0             73.0   26.3         71.0       39.8
# 2936       0            686.0   25.9         75.0       42.1
# 2937       0            665.0   25.5         78.0       43.5
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# ...

# %%
X = x.iloc[:,indices].copy()

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    Status  Adult Mortality   BMI   Diphtheria    HIV/AIDS  \
# 0       0            263.0   19.1         65.0        0.1
# 1       0            271.0   18.6         62.0        0.1
# 2       0            268.0   18.1         64.0        0.1
# 3       0            272.0   17.6         67.0        0.1
# 4       0            275.0   17.2         68.0        0.1
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model2 = LinearRegression()
model2.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred2 = model2.predict(X_test)

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.787519940966617

# %%
model2.score(X_test, y_test)
# Out:
# 0.787519940966617

# %%
print(x.shape)
print(X.shape)
# Out:
# (2888, 12)
# (2888, 7)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_model.estimators_
# Out:
# [DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=949427820, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=94832602, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features='auto', max_leaf_nodes=None,
# ...

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.9580662069081416

# %%
y_pred2 = rf_model.predict(X_test)

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.9580662069081415
